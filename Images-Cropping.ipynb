# %%
import cv2

# %%
from PIL import Image

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
gb = np.array(Image.open(r'D:\Datasets\img.jpg'))
plt.figure(figsize=(10,10))
plt.imshow(gb)
plt.show()

# %%
crop = gb[200:500,:,:]
plt.figure(figsize=(10,10))
plt.imshow(crop)
plt.show()
